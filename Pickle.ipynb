# %% [markdown]
# <a href="https://colab.research.google.com/github/fedev23/Csv/blob/main/Pickle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pickle

# %%
# !pip3 install funpymodeling

# %%
from funpymodeling.exploratory import freq_tbl, status, profiling_num

# %%
data = pd.read_csv("new_data.csv", sep=',')

# %%
respuesta1 = status(data)
respuesta1.to_csv('tarea_respuesta1.csv', index=False)

# %%
data_ohe = pd.get_dummies(data)

# %%
data_ohe
# Out:
#    id  nhogar  miembro  comuna  edad  ingreso_total_lab  ingreso_total_no_lab  \
# 0  21       1        1       3    20                  0                  4000
# 1  22       1        1      12    20                  0                 22000
# 2  23       1        1      14    20              10000                 15000
# 3  23       1        2      14    21              30000                     0
# 4  24       1        1       7    20                  0                 20000
#
#    ingresos_totales  ingresos_familiares  ingreso_per_capita_familiar  ...  \
# 0              4000                 4000                         4000  ...
# 1             22000                22000                        22000  ...
# 2             25000                55000                        27500  ...
# 3             30000                55000                        27500  ...
# 4             20000                20000                        20000  ...
#
# ...

# %%
data_ohe.columns
# Out:
# Index(['id', 'nhogar', 'miembro', 'comuna', 'edad', 'ingreso_total_lab',
#        'ingreso_total_no_lab', 'ingresos_totales', 'ingresos_familiares',
#        'ingreso_per_capita_familiar', 'años_escolaridad',
#        'dominio_Resto de la Ciudad', 'sexo_Mujer', 'sexo_Varon',
#        'parentesco_jefe_Jefe', 'parentesco_jefe_Otro familiar',
#        'situacion_conyugal_Soltero/a',
#        'num_miembro_padre_Padre no vive en el hogar',
#        'num_miembro_madre_Madre no vive en el hogar',
#        'estado_ocupacional_Desocupado', 'estado_ocupacional_Inactivo',
#        'estado_ocupacional_Ocupado', 'cat_ocupacional_Asalariado',
#        'cat_ocupacional_No corresponde',
#        'cat_ocupacional_Trabajador por cuenta propia',
#        'calidad_ingresos_lab_No tuvo ingresos',
#        'calidad_ingresos_lab_Tuvo ingresos pero no declara monto',
#        'calidad_ingresos_lab_Tuvo ingresos y declara monto',
#        'calidad_ingresos_no_lab_No tuvo ingresos',
# ...

# %%
import pickle

with open('categories_ohe.pickle', 'wb') as handle:
    pickle.dump(data_ohe.columns, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ae8297b6a2f4> in <cell line: 3>()
#       2
#       3 with open('categories_ohe.pickle', 'wb') as handle:
# ----> 4     pickle.dump(data_ohe.columns, handle, protocol=pickle.HIGHEST_PROTOCOL)
#
# NameError: name 'data_ohe' is not defined

# %%
new_data = pd.read_csv("new_data.csv", sep=',')

# %%
import pickle

with open('categories_ohe.pickle', 'wb') as handle:
    pickle.dump(data_ohe.columns, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('categories_ohe.pickle', 'rb') as handle:
    ohe_tr = pickle.load(handle)

# %%
ohe_tr
# Out:
# Index(['id', 'nhogar', 'miembro', 'comuna', 'edad', 'ingreso_total_lab',
#        'ingreso_total_no_lab', 'ingresos_totales', 'ingresos_familiares',
#        'ingreso_per_capita_familiar', 'años_escolaridad',
#        'dominio_Resto de la Ciudad', 'sexo_Mujer', 'sexo_Varon',
#        'parentesco_jefe_Jefe', 'parentesco_jefe_Otro familiar',
#        'situacion_conyugal_Soltero/a',
#        'num_miembro_padre_Padre no vive en el hogar',
#        'num_miembro_madre_Madre no vive en el hogar',
#        'estado_ocupacional_Desocupado', 'estado_ocupacional_Inactivo',
#        'estado_ocupacional_Ocupado', 'cat_ocupacional_Asalariado',
#        'cat_ocupacional_No corresponde',
#        'cat_ocupacional_Trabajador por cuenta propia',
#        'calidad_ingresos_lab_No tuvo ingresos',
#        'calidad_ingresos_lab_Tuvo ingresos pero no declara monto',
#        'calidad_ingresos_lab_Tuvo ingresos y declara monto',
#        'calidad_ingresos_no_lab_No tuvo ingresos',
# ...

# %%
pd.get_dummies(new_data).reindex(columns = ohe_tr)
# Out:
#    id  nhogar  miembro  comuna  edad  ingreso_total_lab  ingreso_total_no_lab  \
# 0  21       1        1       3    20                  0                  4000
# 1  22       1        1      12    20                  0                 22000
# 2  23       1        1      14    20              10000                 15000
# 3  23       1        2      14    21              30000                     0
# 4  24       1        1       7    20                  0                 20000
#
#    ingresos_totales  ingresos_familiares  ingreso_per_capita_familiar  ...  \
# 0              4000                 4000                         4000  ...
# 1             22000                22000                        22000  ...
# 2             25000                55000                        27500  ...
# 3             30000                55000                        27500  ...
# 4             20000                20000                        20000  ...
#
# ...

# %%
d_tr_ohe_2 = pd.get_dummies(data).reindex(columns = ohe_tr).fillna(0)

# %%
d_tr_ohe_2
# Out:
#    id  nhogar  miembro  comuna  edad  ingreso_total_lab  ingreso_total_no_lab  \
# 0  21       1        1       3    20                  0                  4000
# 1  22       1        1      12    20                  0                 22000
# 2  23       1        1      14    20              10000                 15000
# 3  23       1        2      14    21              30000                     0
# 4  24       1        1       7    20                  0                 20000
#
#    ingresos_totales  ingresos_familiares  ingreso_per_capita_familiar  ...  \
# 0              4000                 4000                         4000  ...
# 1             22000                22000                        22000  ...
# 2             25000                55000                        27500  ...
# 3             30000                55000                        27500  ...
# 4             20000                20000                        20000  ...
#
# ...

# %%
d_tr_ohe_2.to_csv('tarea_respuesta2.csv', index=False)
